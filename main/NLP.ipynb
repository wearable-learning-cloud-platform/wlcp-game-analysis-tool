# %% [markdown]
# PART I: Extracting the data

# %%
import json
import pandas as pd
from ast import literal_eval
import glob
import csv
import copy
import os

# %% [markdown]
# Load data from fsm_data folder. Currently, the manual analysis do have the game DidYouCatchTheBall, TheDice, and Tangram so we remove them
#
# > Note: the dir variable may differ in the local folder

# %%
data = []
dir = "../fsm-data/*.json"
old_files = sorted(glob.glob(dir, recursive=False))
files = []
for file in old_files:
  if(file != "../fsm-data\TheDice_US.json" and file != "../fsm-data\DidYouCatchTheBall_US.json" and file != "../fsm-data\TangramsRace.json"):
    files.append(file)
print(len(files))
for single_file in files:
    with open(single_file, 'r') as f:
        json_file = json.load(f)
        new_string = json.dumps(json_file, indent = 2)
        print(new_string)
        data.append(json_file)
# print(files)
# Out:
# 6
# {
#   "gameId": "hackers",
#   "teamCount": 2,
#   "playersPerTeam": 3,
#   "username": {
#     "usernameId": ""
#   },
#   "visibility": true,
#   "stateIdCount": 11,
#   "transitionIdCount": 10,
#   "connectionIdCount": 11,
#   "dataLog": false,
#   "states": [
#     {
#       "stateType": "START_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_start",
#       "game": "hackers",
#       "positionX": 0.0,
#       "positionY": 68.501,
#       "inputConnections": [],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_1"
#       ],
#       "globalVariables": []
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_1",
#       "game": "hackers",
#       "positionX": 24.5073,
#       "positionY": 264.074,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_1"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_2"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "welcome to our game this is a game of hackers  press any button to continune\n"
#       },
#       "pictureOutputs": {
#         "Game Wide": {
#           "url": "https://planetsportsandtrophies.com/wp-content/uploads/2022/01/JR34-TY177A-1-300x300.jpg",
#           "scale": 72
#         }
#       },
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_10",
#       "game": "hackers",
#       "positionX": 0.0,
#       "positionY": 627.502,
#       "inputConnections": [],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_11",
#       "game": "hackers",
#       "positionX": 489.5,
#       "positionY": 867.029,
#       "inputConnections": [],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_2",
#       "game": "hackers",
#       "positionX": 182.046,
#       "positionY": 83.4938,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_2",
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_7"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_3",
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_4"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "calculate 9+6=?"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_3",
#       "game": "hackers",
#       "positionX": 229.001,
#       "positionY": 247.997,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_3"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_5"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "great job you go to next question press any button to continue"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_4",
#       "game": "hackers",
#       "positionX": 544.525,
#       "positionY": 44.5562,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_4"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_7"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "oops wrong answer try again press any button"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_5",
#       "game": "hackers",
#       "positionX": 86.4743,
#       "positionY": 515.594,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_5",
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_9"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_6",
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_8"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "19 + 13 =?"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_6",
#       "game": "hackers",
#       "positionX": 60.0,
#       "positionY": 801.0,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_6"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_10"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "good job you go to next question press any button to continue"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_7",
#       "game": "hackers",
#       "positionX": 458.499,
#       "positionY": 668.918,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_8"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_9"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "oops wrong answer try again press any button to continue"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_8",
#       "game": "hackers",
#       "positionX": 316.495,
#       "positionY": 820.566,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_10"
#       ],
#       "outputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_11"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "999 + 99 -10 -8 =?"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "dc5d6e5c0ffd6d1cd249286ced098382_state_9",
#       "game": "hackers",
#       "positionX": 755.398,
#       "positionY": 779.047,
#       "inputConnections": [
#         "dc5d6e5c0ffd6d1cd249286ced098382_connection_11"
#       ],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     }
#   ],
#   "connections": [
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_1",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_start",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_1",
#       "backwardsLoop": false,
#       "transition": null
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_10",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_6",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_8",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_9"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_11",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_8",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_9",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_10"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_2",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_1",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_2",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_1"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_3",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_2",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_3",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_2"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_4",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_2",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_4",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_3"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_5",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_3",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_5",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_4"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_6",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_5",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_6",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_5"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_7",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_4",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_2",
#       "backwardsLoop": true,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_6"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_8",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_5",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_7",
#       "backwardsLoop": false,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_7"
#     },
#     {
#       "connectionId": "dc5d6e5c0ffd6d1cd249286ced098382_connection_9",
#       "game": "hackers",
#       "connectionFrom": "dc5d6e5c0ffd6d1cd249286ced098382_state_7",
#       "connectionTo": "dc5d6e5c0ffd6d1cd249286ced098382_state_5",
#       "backwardsLoop": true,
#       "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_8"
#     }
#   ],
#   "transitions": [
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_1",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_2",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_1_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_1",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_10",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_11",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_10_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_10",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             "1080"
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_10_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_10",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_2",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_3",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_2_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_2",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             "15"
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_2_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_2",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_3",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_4",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_3_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_3",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             ""
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_3_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_3",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_4",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_5",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_4_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_4",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_5",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_6",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_5_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_5",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             "32"
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_5_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_5",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_6",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_7",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_6_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_6",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_7",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_8",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_7_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_7",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             ""
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_7_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_7",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_8",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_9",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_8_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_8",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_9",
#       "game": "hackers",
#       "connection": "dc5d6e5c0ffd6d1cd249286ced098382_connection_10",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "dc5d6e5c0ffd6d1cd249286ced098382_transition_9_game_wide",
#           "transition": "dc5d6e5c0ffd6d1cd249286ced098382_transition_9",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     }
#   ]
# }
# {
#   "gameId": "indianboys",
#   "teamCount": 3,
#   "playersPerTeam": 3,
#   "username": {
#     "usernameId": ""
#   },
#   "visibility": true,
#   "stateIdCount": 3,
#   "transitionIdCount": 1,
#   "connectionIdCount": 3,
#   "dataLog": false,
#   "states": [
#     {
#       "stateType": "START_STATE",
#       "stateId": "09e8a827b41c13d8ed9a476b3565b52f_start",
#       "game": "indianboys",
#       "positionX": 525.0,
#       "positionY": 100.0,
#       "inputConnections": [],
#       "outputConnections": [
#         "09e8a827b41c13d8ed9a476b3565b52f_connection_1"
#       ],
#       "globalVariables": []
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "09e8a827b41c13d8ed9a476b3565b52f_state_1",
#       "game": "indianboys",
#       "positionX": 325.0,
#       "positionY": 136.0,
#       "inputConnections": [
#         "09e8a827b41c13d8ed9a476b3565b52f_connection_1"
#       ],
#       "outputConnections": [
#         "09e8a827b41c13d8ed9a476b3565b52f_connection_2"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "welcome to the indian boys game"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "09e8a827b41c13d8ed9a476b3565b52f_state_2",
#       "game": "indianboys",
#       "positionX": 397.0,
#       "positionY": 401.0,
#       "inputConnections": [
#         "09e8a827b41c13d8ed9a476b3565b52f_connection_2"
#       ],
#       "outputConnections": [
#         "09e8a827b41c13d8ed9a476b3565b52f_connection_3"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "a ring if or -1 total 20 pointes cricket "
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "09e8a827b41c13d8ed9a476b3565b52f_state_3",
#       "game": "indianboys",
#       "positionX": 300.0,
#       "positionY": 572.0,
#       "inputConnections": [
#         "09e8a827b41c13d8ed9a476b3565b52f_connection_3"
#       ],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     }
#   ],
#   "connections": [
#     {
#       "connectionId": "09e8a827b41c13d8ed9a476b3565b52f_connection_1",
#       "game": "indianboys",
#       "connectionFrom": "09e8a827b41c13d8ed9a476b3565b52f_start",
#       "connectionTo": "09e8a827b41c13d8ed9a476b3565b52f_state_1",
#       "backwardsLoop": false,
#       "transition": null
#     },
#     {
#       "connectionId": "09e8a827b41c13d8ed9a476b3565b52f_connection_2",
#       "game": "indianboys",
#       "connectionFrom": "09e8a827b41c13d8ed9a476b3565b52f_state_1",
#       "connectionTo": "09e8a827b41c13d8ed9a476b3565b52f_state_2",
#       "backwardsLoop": false,
#       "transition": "09e8a827b41c13d8ed9a476b3565b52f_transition_1"
#     },
#     {
#       "connectionId": "09e8a827b41c13d8ed9a476b3565b52f_connection_3",
#       "game": "indianboys",
#       "connectionFrom": "09e8a827b41c13d8ed9a476b3565b52f_state_2",
#       "connectionTo": "09e8a827b41c13d8ed9a476b3565b52f_state_3",
#       "backwardsLoop": false,
#       "transition": null
#     }
#   ],
#   "transitions": [
#     {
#       "transitionId": "09e8a827b41c13d8ed9a476b3565b52f_transition_1",
#       "game": "indianboys",
#       "connection": "09e8a827b41c13d8ed9a476b3565b52f_connection_2",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "09e8a827b41c13d8ed9a476b3565b52f_transition_1_game_wide",
#           "transition": "09e8a827b41c13d8ed9a476b3565b52f_transition_1",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     }
#   ]
# }
# {
#   "gameId": "indiangirls",
#   "teamCount": 3,
#   "playersPerTeam": 3,
#   "username": {
#     "usernameId": ""
#   },
#   "visibility": true,
#   "stateIdCount": 5,
#   "transitionIdCount": 5,
#   "connectionIdCount": 6,
#   "dataLog": false,
#   "states": [
#     {
#       "stateType": "START_STATE",
#       "stateId": "41f33a22c46f8acd99ec10720d82dd57_start",
#       "game": "indiangirls",
#       "positionX": 37.0,
#       "positionY": 24.0,
#       "inputConnections": [],
#       "outputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_1"
#       ],
#       "globalVariables": []
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "41f33a22c46f8acd99ec10720d82dd57_state_1",
#       "game": "indiangirls",
#       "positionX": 102.0,
#       "positionY": 158.0,
#       "inputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_1"
#       ],
#       "outputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_2"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "welcome to indiangirls team                                   push any button to continue"
#       },
#       "pictureOutputs": {
#         "Game Wide": {
#           "url": "https://i.pinimg.com/474x/0c/ff/42/0cff4251788fe1aaeddbf72a14ab35d0.jpg",
#           "scale": 66
#         }
#       },
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "41f33a22c46f8acd99ec10720d82dd57_state_2",
#       "game": "indiangirls",
#       "positionX": 587.0,
#       "positionY": 86.0,
#       "inputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_2",
#         "41f33a22c46f8acd99ec10720d82dd57_connection_6"
#       ],
#       "outputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_3",
#         "41f33a22c46f8acd99ec10720d82dd57_connection_4"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "what is 7+3=?\n"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "41f33a22c46f8acd99ec10720d82dd57_state_3",
#       "game": "indiangirls",
#       "positionX": 912.0,
#       "positionY": 316.0,
#       "inputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_3"
#       ],
#       "outputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_5"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "good job"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "41f33a22c46f8acd99ec10720d82dd57_state_4",
#       "game": "indiangirls",
#       "positionX": 526.0,
#       "positionY": 397.0,
#       "inputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_4"
#       ],
#       "outputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_6"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "please try again"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "41f33a22c46f8acd99ec10720d82dd57_state_5",
#       "game": "indiangirls",
#       "positionX": 660.0,
#       "positionY": 653.0,
#       "inputConnections": [
#         "41f33a22c46f8acd99ec10720d82dd57_connection_5"
#       ],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     }
#   ],
#   "connections": [
#     {
#       "connectionId": "41f33a22c46f8acd99ec10720d82dd57_connection_1",
#       "game": "indiangirls",
#       "connectionFrom": "41f33a22c46f8acd99ec10720d82dd57_start",
#       "connectionTo": "41f33a22c46f8acd99ec10720d82dd57_state_1",
#       "backwardsLoop": false,
#       "transition": null
#     },
#     {
#       "connectionId": "41f33a22c46f8acd99ec10720d82dd57_connection_2",
#       "game": "indiangirls",
#       "connectionFrom": "41f33a22c46f8acd99ec10720d82dd57_state_1",
#       "connectionTo": "41f33a22c46f8acd99ec10720d82dd57_state_2",
#       "backwardsLoop": false,
#       "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_1"
#     },
#     {
#       "connectionId": "41f33a22c46f8acd99ec10720d82dd57_connection_3",
#       "game": "indiangirls",
#       "connectionFrom": "41f33a22c46f8acd99ec10720d82dd57_state_2",
#       "connectionTo": "41f33a22c46f8acd99ec10720d82dd57_state_3",
#       "backwardsLoop": false,
#       "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_2"
#     },
#     {
#       "connectionId": "41f33a22c46f8acd99ec10720d82dd57_connection_4",
#       "game": "indiangirls",
#       "connectionFrom": "41f33a22c46f8acd99ec10720d82dd57_state_2",
#       "connectionTo": "41f33a22c46f8acd99ec10720d82dd57_state_4",
#       "backwardsLoop": false,
#       "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_3"
#     },
#     {
#       "connectionId": "41f33a22c46f8acd99ec10720d82dd57_connection_5",
#       "game": "indiangirls",
#       "connectionFrom": "41f33a22c46f8acd99ec10720d82dd57_state_3",
#       "connectionTo": "41f33a22c46f8acd99ec10720d82dd57_state_5",
#       "backwardsLoop": false,
#       "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_5"
#     },
#     {
#       "connectionId": "41f33a22c46f8acd99ec10720d82dd57_connection_6",
#       "game": "indiangirls",
#       "connectionFrom": "41f33a22c46f8acd99ec10720d82dd57_state_4",
#       "connectionTo": "41f33a22c46f8acd99ec10720d82dd57_state_2",
#       "backwardsLoop": true,
#       "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4"
#     }
#   ],
#   "transitions": [
#     {
#       "transitionId": "41f33a22c46f8acd99ec10720d82dd57_transition_1",
#       "game": "indiangirls",
#       "connection": "41f33a22c46f8acd99ec10720d82dd57_connection_2",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_1_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_1",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "41f33a22c46f8acd99ec10720d82dd57_transition_2",
#       "game": "indiangirls",
#       "connection": "41f33a22c46f8acd99ec10720d82dd57_connection_3",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "41f33a22c46f8acd99ec10720d82dd57_transition_2_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_2",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             "10",
#             "ten"
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_2_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_2",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "41f33a22c46f8acd99ec10720d82dd57_transition_3",
#       "game": "indiangirls",
#       "connection": "41f33a22c46f8acd99ec10720d82dd57_connection_4",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "41f33a22c46f8acd99ec10720d82dd57_transition_3_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_3",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             ""
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_3_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_3",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#       "game": "indiangirls",
#       "connection": "41f33a22c46f8acd99ec10720d82dd57_connection_6",
#       "activeTransitions": {
#         "Team 2 Player 1": "Button Press",
#         "Team 3": "Button Press",
#         "Team 2 Player 2": "Button Press",
#         "Team 2 Player 3": "Button Press",
#         "Team 3 Player 2": "Button Press",
#         "Team 3 Player 1": "Button Press",
#         "Team 3 Player 3": "Button Press",
#         "Game Wide": "Button Press",
#         "Team 1": "Button Press",
#         "Team 2": "Button Press",
#         "Team 1 Player 1": "Button Press",
#         "Team 1 Player 2": "Button Press",
#         "Team 1 Player 3": "Button Press"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Team 2 Player 1": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_2 player 1",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 2 Player 1",
#           "globalVariableInputModifiers": []
#         },
#         "Team 3": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_3",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 3",
#           "globalVariableInputModifiers": []
#         },
#         "Team 2 Player 2": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_2 player 2",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 2 Player 2",
#           "globalVariableInputModifiers": []
#         },
#         "Team 2 Player 3": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_2 player 3",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 2 Player 3",
#           "globalVariableInputModifiers": []
#         },
#         "Team 3 Player 2": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_3 player 2",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 3 Player 2",
#           "globalVariableInputModifiers": []
#         },
#         "Team 3 Player 1": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_3 player 1",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 3 Player 1",
#           "globalVariableInputModifiers": []
#         },
#         "Team 3 Player 3": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_3 player 3",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 3 Player 3",
#           "globalVariableInputModifiers": []
#         },
#         "Game Wide": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         },
#         "Team 1": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_1",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 1",
#           "globalVariableInputModifiers": []
#         },
#         "Team 2": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_2",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 2",
#           "globalVariableInputModifiers": []
#         },
#         "Team 1 Player 1": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_1 player 1",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 1 Player 1",
#           "globalVariableInputModifiers": []
#         },
#         "Team 1 Player 2": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_1 player 2",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 1 Player 2",
#           "globalVariableInputModifiers": []
#         },
#         "Team 1 Player 3": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_4_team_1 player 3",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_4",
#           "scope": "Team 1 Player 3",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "41f33a22c46f8acd99ec10720d82dd57_transition_5",
#       "game": "indiangirls",
#       "connection": "41f33a22c46f8acd99ec10720d82dd57_connection_5",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "41f33a22c46f8acd99ec10720d82dd57_transition_5_game_wide",
#           "transition": "41f33a22c46f8acd99ec10720d82dd57_transition_5",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     }
#   ]
# }
# {
#   "gameId": "math Parkour",
#   "teamCount": 1,
#   "playersPerTeam": 1,
#   "username": {
#     "usernameId": ""
#   },
#   "visibility": true,
#   "stateIdCount": 16,
#   "transitionIdCount": 14,
#   "connectionIdCount": 15,
#   "dataLog": false,
#   "states": [
#     {
#       "stateType": "START_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_start",
#       "game": "math Parkour",
#       "positionX": 488.0,
#       "positionY": 100.0,
#       "inputConnections": [],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_1"
#       ],
#       "globalVariables": []
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_1",
#       "game": "math Parkour",
#       "positionX": 465.0,
#       "positionY": 232.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_1"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_2"
#       ],
#       "description": "welcome!!!!",
#       "displayText": {
#         "Game Wide": "    Welcome to MATH \n       !!PARKOUR!!\n\n(: Enter \"Play\" to begin :)"
#       },
#       "pictureOutputs": {
#         "Game Wide": {
#           "url": "https://dev.wearablelearning.org/wlcp-api/objectStoreController/files/4d3e488b-1804-4756-a9b7-e4aeab184901",
#           "scale": 76
#         }
#       },
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_10",
#       "game": "math Parkour",
#       "positionX": 483.0,
#       "positionY": 2326.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_9"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_10"
#       ],
#       "description": "questoin 7",
#       "displayText": {
#         "Game Wide": "73-49"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_11",
#       "game": "math Parkour",
#       "positionX": 486.0,
#       "positionY": 2578.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_10"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_11"
#       ],
#       "description": "question 8",
#       "displayText": {
#         "Game Wide": "40x9"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_12",
#       "game": "math Parkour",
#       "positionX": 503.0,
#       "positionY": 2832.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_11"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_12"
#       ],
#       "description": "question 9",
#       "displayText": {
#         "Game Wide": "64+64"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_13",
#       "game": "math Parkour",
#       "positionX": 497.0,
#       "positionY": 3082.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_12"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_13"
#       ],
#       "description": "question 10",
#       "displayText": {
#         "Game Wide": "134x2"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_14",
#       "game": "math Parkour",
#       "positionX": 517.0,
#       "positionY": 3332.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_13"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_14"
#       ],
#       "description": "question 11",
#       "displayText": {
#         "Game Wide": "45x3"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_15",
#       "game": "math Parkour",
#       "positionX": 540.0,
#       "positionY": 3553.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_14"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_15"
#       ],
#       "description": "question 12",
#       "displayText": {
#         "Game Wide": "9x12"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_16",
#       "game": "math Parkour",
#       "positionX": 557.0,
#       "positionY": 3785.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_15"
#       ],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_2",
#       "game": "math Parkour",
#       "positionX": 463.0,
#       "positionY": 451.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_2"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_3"
#       ],
#       "description": " insturctions",
#       "displayText": {
#         "Game Wide": "In order to get to the end you must asnswer all math questions in order to win :)     There are 10 questions.\n\npress enter to continue"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_3",
#       "game": "math Parkour",
#       "positionX": 461.0,
#       "positionY": 730.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_3"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_4"
#       ],
#       "description": "question 1",
#       "displayText": {
#         "Game Wide": "2x8\n put in the correct answer to continue ;)"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {
#         "Game Wide": {
#           "url": "https://dev.wearablelearning.org/wlcp-api/objectStoreController/files/27255dd2-a7cd-43c6-a4a1-d725703f13ba"
#         }
#       },
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_5",
#       "game": "math Parkour",
#       "positionX": 446.0,
#       "positionY": 984.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_4"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_5"
#       ],
#       "description": "question 2",
#       "displayText": {
#         "Game Wide": "11x5"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_6",
#       "game": "math Parkour",
#       "positionX": 453.0,
#       "positionY": 1238.0,
#       "inputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_5"
#       ],
#       "outputConnections": [
#         "fe5d603d88e3ac6fdc17d910e75b8eda_connection_6"
#       ],
#       "description": "question 3",
#       "displayText": {
#         "Game Wide": "112-20"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "fe5d603d88e3ac6fdc17d910e75b8eda_state_7",
#       "game": "math Parkour",
#       "positionX": 462.0,
# ...
#       "transitionId": "1b924414902736aef127e558c1720310_transition_8",
#       "game": "raistar",
#       "connection": "1b924414902736aef127e558c1720310_connection_9",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "1b924414902736aef127e558c1720310_transition_8_game_wide",
#           "transition": "1b924414902736aef127e558c1720310_transition_8",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "1b924414902736aef127e558c1720310_transition_9",
#       "game": "raistar",
#       "connection": "1b924414902736aef127e558c1720310_connection_11",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "1b924414902736aef127e558c1720310_transition_9_game_wide",
#           "transition": "1b924414902736aef127e558c1720310_transition_9",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     }
#   ]
# }
# {
#   "gameId": "fireballs20",
#   "teamCount": 2,
#   "playersPerTeam": 2,
#   "username": {
#     "usernameId": ""
#   },
#   "visibility": true,
#   "stateIdCount": 8,
#   "transitionIdCount": 7,
#   "connectionIdCount": 12,
#   "dataLog": false,
#   "states": [
#     {
#       "stateType": "START_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_start",
#       "game": "fireballs20",
#       "positionX": 871.0,
#       "positionY": 237.0,
#       "inputConnections": [],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_1"
#       ],
#       "globalVariables": []
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_1",
#       "game": "fireballs20",
#       "positionX": 830.0,
#       "positionY": 399.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_1"
#       ],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_2"
#       ],
#       "description": "welcome screen",
#       "displayText": {
#         "Game Wide": "Welcome to mathematics. Tap a button to continue."
#       },
#       "pictureOutputs": {
#         "Game Wide": {
#           "url": "https://dev.wearablelearning.org/wlcp-api/objectStoreController/files/12dd37ea-7caa-442a-8a96-6264dfc570ba",
#           "scale": 31
#         }
#       },
#       "soundOutputs": {
#         "Game Wide": {
#           "url": "https://dev.wearablelearning.org/wlcp-api/objectStoreController/files/de7fef01-4174-4438-9859-d1ea5190bbfe"
#         }
#       },
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_2",
#       "game": "fireballs20",
#       "positionX": 708.0,
#       "positionY": 621.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_2",
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_6"
#       ],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_3",
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_5"
#       ],
#       "description": "question 1",
#       "displayText": {
#         "Game Wide": "10-30 =?"
#       },
#       "pictureOutputs": {
#         "Game Wide": {
#           "url": "https://studiousguy.com/wp-content/uploads/2019/10/maths-applications.jpg",
#           "scale": 48
#         }
#       },
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_3",
#       "game": "fireballs20",
#       "positionX": 539.0,
#       "positionY": 1201.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_4"
#       ],
#       "outputConnections": [],
#       "description": "q2 correct response ",
#       "displayText": {
#         "Game Wide": "That is correct!! Great work. Now, lets go to level 2"
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_4",
#       "game": "fireballs20",
#       "positionX": 889.0,
#       "positionY": 878.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_3"
#       ],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_4",
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_7"
#       ],
#       "description": "question 2",
#       "displayText": {
#         "Game Wide": "Great work! Here is another. Try 17 times 3."
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_5",
#       "game": "fireballs20",
#       "positionX": 523.0,
#       "positionY": 836.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_5"
#       ],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_6"
#       ],
#       "description": "State",
#       "displayText": {
#         "Game Wide": "Ooops thats wrong.:( Try agaun."
#       },
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_6",
#       "game": "fireballs20",
#       "positionX": 1136.0,
#       "positionY": 1122.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_7"
#       ],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_8"
#       ],
#       "description": "lev2",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_7",
#       "game": "fireballs20",
#       "positionX": 886.0,
#       "positionY": 1255.0,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_8"
#       ],
#       "outputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_9"
#       ],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     },
#     {
#       "stateType": "OUTPUT_STATE",
#       "stateId": "74b8d4d700075b33d5794c0bcf45efcf_state_8",
#       "game": "fireballs20",
#       "positionX": 559.0,
#       "positionY": 1527.25,
#       "inputConnections": [
#         "74b8d4d700075b33d5794c0bcf45efcf_connection_9"
#       ],
#       "outputConnections": [],
#       "description": "State",
#       "displayText": {},
#       "pictureOutputs": {},
#       "soundOutputs": {},
#       "videoOutputs": {},
#       "globalVariables": {}
#     }
#   ],
#   "connections": [
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_1",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_start",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_1",
#       "backwardsLoop": false,
#       "transition": null
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_2",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_1",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_2",
#       "backwardsLoop": false,
#       "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_1"
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_3",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_2",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_4",
#       "backwardsLoop": false,
#       "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_2"
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_4",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_4",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_3",
#       "backwardsLoop": false,
#       "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_6"
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_5",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_2",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_5",
#       "backwardsLoop": false,
#       "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_3"
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_6",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_5",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_2",
#       "backwardsLoop": true,
#       "transition": null
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_7",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_4",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_6",
#       "backwardsLoop": false,
#       "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_7"
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_8",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_6",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_7",
#       "backwardsLoop": false,
#       "transition": null
#     },
#     {
#       "connectionId": "74b8d4d700075b33d5794c0bcf45efcf_connection_9",
#       "game": "fireballs20",
#       "connectionFrom": "74b8d4d700075b33d5794c0bcf45efcf_state_7",
#       "connectionTo": "74b8d4d700075b33d5794c0bcf45efcf_state_8",
#       "backwardsLoop": false,
#       "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_4"
#     }
#   ],
#   "transitions": [
#     {
#       "transitionId": "74b8d4d700075b33d5794c0bcf45efcf_transition_1",
#       "game": "fireballs20",
#       "connection": "74b8d4d700075b33d5794c0bcf45efcf_connection_2",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {
#         "Game Wide": {
#           "button1": true,
#           "button1Label": "Red Button",
#           "button2": true,
#           "button2Label": "Green Button",
#           "button3": true,
#           "button3Label": "Blue Button",
#           "button4": true,
#           "button4Label": "Black Button"
#         }
#       },
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "74b8d4d700075b33d5794c0bcf45efcf_transition_1_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_1",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "74b8d4d700075b33d5794c0bcf45efcf_transition_2",
#       "game": "fireballs20",
#       "connection": "74b8d4d700075b33d5794c0bcf45efcf_connection_3",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "74b8d4d700075b33d5794c0bcf45efcf_transition_2_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_2",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             "-20"
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "74b8d4d700075b33d5794c0bcf45efcf_transition_2_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_2",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "74b8d4d700075b33d5794c0bcf45efcf_transition_3",
#       "game": "fireballs20",
#       "connection": "74b8d4d700075b33d5794c0bcf45efcf_connection_5",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "74b8d4d700075b33d5794c0bcf45efcf_transition_3_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_3",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             ""
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "74b8d4d700075b33d5794c0bcf45efcf_transition_3_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_3",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "74b8d4d700075b33d5794c0bcf45efcf_transition_4",
#       "game": "fireballs20",
#       "connection": "74b8d4d700075b33d5794c0bcf45efcf_connection_9",
#       "activeTransitions": {},
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {}
#     },
#     {
#       "transitionId": "74b8d4d700075b33d5794c0bcf45efcf_transition_6",
#       "game": "fireballs20",
#       "connection": "74b8d4d700075b33d5794c0bcf45efcf_connection_4",
#       "activeTransitions": {
#         "Game Wide": "Text Entry"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {
#         "Game Wide": {
#           "keyboardInputId": "74b8d4d700075b33d5794c0bcf45efcf_transition_6_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_6",
#           "scope": "Game Wide",
#           "keyboardInputs": [
#             "51"
#           ]
#         }
#       },
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "74b8d4d700075b33d5794c0bcf45efcf_transition_6_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_6",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     },
#     {
#       "transitionId": "74b8d4d700075b33d5794c0bcf45efcf_transition_7",
#       "game": "fireballs20",
#       "connection": "74b8d4d700075b33d5794c0bcf45efcf_connection_7",
#       "activeTransitions": {
#         "Game Wide": "Button Press"
#       },
#       "singleButtonPresses": {},
#       "sequenceButtonPresses": {},
#       "keyboardInputs": {},
#       "timerDurations": {},
#       "randoms": {},
#       "globalVariables": {
#         "Game Wide": {
#           "globalVariableId": "74b8d4d700075b33d5794c0bcf45efcf_transition_7_game_wide",
#           "transition": "74b8d4d700075b33d5794c0bcf45efcf_transition_7",
#           "scope": "Game Wide",
#           "globalVariableInputModifiers": []
#         }
#       }
#     }
#   ]
# }

# %% [markdown]
# Extract all of the text in the game. The considered text are from 'displayText' attribute in the json file

# %%
c = []
for single_file in data:
    temp = single_file['states']
    d = []
    #print('------------------------------')
    for i in temp:
        att = list(i.keys())
        for key in att:
            if (key == 'displayText'):
                s = ''
                text = list(i[key].keys())
                for j in text:
                    s += i[key][j]
                if (not (s == '')):
                    d.append(s)
    c.append(d)

# %% [markdown]
# Extracting the data from csv file in manual_data folder, and turn them into pandas DataFrame
#
#
# > Note: All csv need to be in the same name as the json file to keep the proper order (the right input goes with the right output). Furthermore, the number of files in both input and output must be the same (cannot have more input or have more output than the other)
#
# We also drop some of the unneccessary columns (criterias that seems unrelated to NLP)

# %%
dir_csv = '../manual-analysis/*.csv'
csv_files = sorted(glob.glob(dir_csv, recursive=False))
for file in csv_files:
   if(file == "../manual-analysis\Mortal_Gorilla_Sheet1.csv"):
      csv_files.remove(file)
df_list = (pd.read_csv(file) for file in csv_files)
labels = list(df_list)
for y in labels:
   y.drop(columns=["NAME","Day","Targeted Grade Level","Presence of Teams", "Team Dynamics No Teams", "Team Size", "Number of Teams", "Team Dynamics Between Teams", "Team Dynamics Within Teams", "Drawing Components [Rules]", "Drawing Components [Physical Objects]", "Drawing Components [Physical Space]", "Drawing Components [Timing]", "Drawing Components [Physicality]", "FSMD Components [Rules]", "FSMD Components [Physical Objects]", "FSMD Components [Physical Space]", "FSMD Components [Timing]", "FSMD Components [Physicality]", "Presence of Finite State Machine Diagram", "Output State Representation", "Transition State Representation", "Finite State Machine Diagram Consistency with Specified Rules", "State Consistency (Boxes)", "Transition Consistency (Arrows)", "Finite State Machine Diagram Completion", "States/Boxes", "Transitions/Arrows", "Numbered States", "Evidence of Programming Language Knowledge [Arrow(s) that loop to a previous state]"], inplace = True)

# %% [markdown]
# Keep the input and output as a single DataFrame (may be deleted later)

# %%
li = []
for names in csv_files:
  dft = pd.read_csv(names, index_col=None, header=0)
  dft.drop(columns=["NAME","Day","Targeted Grade Level","Presence of Teams", "Team Dynamics No Teams", "Team Size", "Number of Teams", "Team Dynamics Between Teams", "Team Dynamics Within Teams", "Drawing Components [Rules]", "Drawing Components [Physical Objects]", "Drawing Components [Physical Space]", "Drawing Components [Timing]", "Drawing Components [Physicality]", "FSMD Components [Rules]", "FSMD Components [Physical Objects]", "FSMD Components [Physical Space]", "FSMD Components [Timing]", "FSMD Components [Physicality]", "Presence of Finite State Machine Diagram", "Output State Representation", "Transition State Representation", "Finite State Machine Diagram Consistency with Specified Rules", "State Consistency (Boxes)", "Transition Consistency (Arrows)", "Finite State Machine Diagram Completion", "States/Boxes", "Transitions/Arrows", "Numbered States", "Evidence of Programming Language Knowledge [Arrow(s) that loop to a previous state]"], inplace = True)
  li.append(dft)
frame = pd.concat(li, axis=0, ignore_index=True)
x = []
for col in frame.columns:
  if (col != 'Input'):
    x.append(col)

print(x)
# Out:
# ['Game Descriptor', 'Content [Counting and Cardinality ]', 'Content [Operations and Algebraic Thinking ]', 'Content [Number and Operations in Base Ten]', 'Content [Number and Operations with Fractions]', 'Content [Measurement and Data]', 'Content [Geometry]', 'Content [Ratio and Proportions]', 'Content [The Number System]', 'Content [Expressions and Equations]', 'Content [Functions]', 'Content [Statistics and Probability ]', 'Progressive Levels', 'Content Adaptability', 'Game Facilitator', 'End-Goal', 'Technological Incorporation', 'Technological Dependency', 'Player Competition (No Teams)', 'Player Collaboration', 'Team Competition', 'Team Collaboration', 'Facilitator Competition', 'Facilitator Collaboration', 'Physicality', 'Physicality Option', 'Sweat Factor', 'Physical Contact', 'Style of Physical Contact', 'Physical Space Diagram', 'Physical Environment', 'If you selected 0 (Unspecified), select one of the following codes related to the size of the environment for gameplay based on the students’ descriptions.', 'Motor Action and Math Relationship', 'Mathematical Importance', 'Mathematical Utilization', 'Written Narrative Components [Rules]', 'Written Narrative Components [Physical Objects]', 'Written Narrative Components [Physical Space]', 'Written Narrative Components [Timing]', 'Written Narrative Components [Physicality]', 'Input Types [RFID]', 'Input Types [Buttons]', 'Input Types [GPS]', 'Input Types [Keyboard]', 'Input Types [Touch Interface]', 'Input Types [Timer]', 'Input Types [Other User]', 'Specification of Mistakes', 'Domain Level: Management-Level', 'Domain Level: Team-Level', 'Domain Level: Player-Level', 'Labeled Arrows (includes input to transition; excludes numbers)', 'Evidence of Programming Language Knowledge [A reference to “If-then” Statements]', 'Evidence of Programming Language Knowledge [A reference to “While” Loops; or “Do this... until ...”]']

# %%
# pip install transformers

# %%
import pandas as pd
import torch
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import DistilBertTokenizer, DistilBertModel

# %% [markdown]
# Initializing the size for our input to feed to the model

# %%
MAX_LEN = 133
TRAIN_BATCH_SIZE = 4
VALID_BATCH_SIZE = 2 
EPOCHS = 3
LEARNING_RATE = 1e-05
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cpu

# %% [markdown]
# The following two cells create a single DataFrame that holds the input text and the labels

# %%
input = []
for arr in c:
  temp = ''
  for i in arr:
    i+='.'
    temp += i
  input.append(temp)

# %%
tempf = []
for u in labels:
  tempt = []
  for k in x:
    t = (u[k].values)[0]
    tempt.append(t)
  tempf.append(tempt)

dataf = {'Input': input, 'Output': tempf}
train_data = pd.DataFrame(dataf)
# print(df)

# %% [markdown]
# PART II: Building the model

# %% [markdown]
# We define a PyTorch Dataset class called MultiLabelDataset that is used to preprocess text data for multi-label text classification tasks using the DistilBERT model.
#
# We put our DataFrame into the class and it will tokenize the text (in a way needed for BERT), generate the attention mask and put all of them in a Tensor object.
#
# More info about the tokenization process: BERT needs the input to be breaks down into smaller tokens and padd all inputs to be the same length (also, all sentences must be padded with the '[CLS]' and '[SEP]' tokens at start and end)

# %%
class MultiLabelDataset(Dataset):

    def __init__(self, dataframe, tokenizer, max_len, new_data=False):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.text = dataframe.Input
        self.new_data = new_data
        
        if not new_data:
            self.targets = self.data.Output
        self.max_len = max_len

    def __len__(self):
        return len(self.text)

    def __getitem__(self, index):
        text = str(self.text[index])
        text = " ".join(text.split())

        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]

        out = {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
        }
        
        if not self.new_data:
            out['targets'] = torch.tensor(self.targets[index], dtype=torch.float)

        return out

# %% [markdown]
# Split out data into training set and validation set

# %%
train_size = 0.7

train_df = train_data.sample(frac=train_size, random_state=123)
val_df = train_data.drop(train_df.index).reset_index(drop=True)
train_df = train_df.reset_index(drop=True)


print("Orig Dataset: {}".format(train_data.shape))
print("Training Dataset: {}".format(train_df.shape))
print("Validation Dataset: {}".format(val_df.shape))

tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased', truncation=True, do_lower_case=True)
training_set = MultiLabelDataset(train_df, tokenizer, MAX_LEN)
val_set = MultiLabelDataset(val_df, tokenizer, MAX_LEN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\vtminh\Documents\UMass deadly\2nd year\cs396A\wlcp-game-analysis-tool\main\NLP.ipynb Cell 22 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/vtminh/Documents/UMass%20deadly/2nd%20year/cs396A/wlcp-game-analysis-tool/main/NLP.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> train_size = 0.7
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vtminh/Documents/UMass%20deadly/2nd%20year/cs396A/wlcp-game-analysis-tool/main/NLP.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> train_df = train_data.sample(frac=train_size, random_state=123)
#       <a href='vscode-notebook-cell:/c%3A/Users/vtminh/Documents/UMass%20deadly/2nd%20year/cs396A/wlcp-game-analysis-tool/main/NLP.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> val_df = train_data.drop(train_df.index).reset_index(drop=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/vtminh/Documents/UMass%20deadly/2nd%20year/cs396A/wlcp-game-analysis-tool/main/NLP.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> train_df = train_df.reset_index(drop=True)
#
# NameError: name 'train_data' is not defined

# %%
train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 8
                }

val_params = {'batch_size': VALID_BATCH_SIZE,
               'shuffle': False,
               'num_workers': 8
                }

training_loader = DataLoader(training_set, **train_params)

# %% [markdown]
# This is a model that is built up on DistilBertModel, which is a lighter, faster version of the normal Bert Model.
#
# When calling forward(), the model breaks down the inputs into hidden states, which refer to the internal representation of a sequence of text, such as a sentence or a document, that is learned by a machine learning model
#
# In the case of the DistilBERT model, the hidden state refers to the internal representation of the input text at each layer of the model. Each layer of the model takes the output of the previous layer and produces a new hidden state that captures increasingly complex and abstract features of the input text. The final hidden state of the last layer, corresponding to the [CLS] token in the input sequence, is typically used as the input to downstream tasks such as text classification, question answering, or text generation.
#
# After we have the hidden states, the model run the classifer, which is a sequence of three layers. The last layer would be a fully connected layer with 768 input neurons and 54 output neurons (54 represents our classes). The output of this classifier will be used to predict the classification label of the input text.
#
# Having multiple layers of transformers allows the model to capture increasingly complex and abstract features of the input text, as each layer can build on the representations learned by the previous layer. However, increasing the number of layers can also make the model more prone to overfitting, as it may start to memorize the training data instead of learning general patterns.

# %%
class DistilBERTClass(torch.nn.Module):
    def __init__(self):
        super(DistilBERTClass, self).__init__()
        
        self.bert = DistilBertModel.from_pretrained("distilbert-base-uncased")
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(768, 768),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.1),
            torch.nn.Linear(768, 54)
        )

    def forward(self, input_ids, attention_mask, token_type_ids):
        output_1 = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        hidden_state = output_1[0]
        out = hidden_state[:, 0]
        out = self.classifier(out)
        return out

model = DistilBERTClass()
model.to(DEVICE)
# Out:
# Downloading pytorch_model.bin: 100%|██████████| 268M/268M [03:38<00:00, 1.23MB/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# DistilBERTClass(
#   (bert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=768, out_features=768, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=768, out_features=54, bias=True)
#   )
# )

# %% [markdown]
# The optimizer is an algorithm used during the training of a neural network to adjust the model's weights and biases based on the computed gradients of the loss function. The goal of the optimizer is to minimize the loss function and improve the accuracy of the model's predictions.
# The Adam optimizer is a popular optimization algorithm that is commonly used in deep learning. It is an extension of stochastic gradient descent (SGD) and is known for its ability to converge quickly and efficiently, even for large and complex models.

# %%
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# During one epoch, the model receives the entire training dataset, processes it forward and backward through the network, and updates the model parameters.
#
# The train function is called for each epoch and sets the model to training mode using model.train(). It then iterates over the batches in the training_loader, loads the batch data onto the DEVICE, and passes it through the model to obtain the outputs.
#
# The optimizer's gradients are set to zero with optimizer.zero_grad() to prevent accumulation of gradients from previous batches. The loss is computed using the binary_cross_entropy_with_logits function from torch.nn.functional. This function computes the binary cross-entropy loss between the outputs and the targets.
#
# loss.backward() computes the gradients of the binary cross-entropy loss with respect to each parameter of the model, which is then used by the optimizer to update the model parameters in the next step of the training loop

# %%
def train(epoch):
    model.train()
    for _, data in tqdm(enumerate(training_loader, 0)):
        ids = data['ids'].to(DEVICE, dtype=torch.long)
        mask = data['mask'].to(DEVICE, dtype=torch.long)
        token_type_ids = data['token_type_ids'].to(DEVICE, dtype=torch.long)
        targets = data['targets'].to(DEVICE, dtype=torch.float)

        outputs = model(ids, mask, token_type_ids)
        print(outputs)
        optimizer.zero_grad()
        loss = torch.nn.functional.binary_cross_entropy_with_logits(outputs, targets)
        
        if _ % 5000 == 0:
            print(f'Epoch: {epoch}, Loss:  {loss.item()}')
        
        loss.backward()
        optimizer.step()

for epoch in range(EPOCHS):
    train(epoch)
